# %% [markdown]
# # Pandas
# Pandas is a powerful and open-source Python library. The Pandas library is used for data manipulation and analysis. Pandas consist of data structures and functions to perform efficient operations on data.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Working with CSV files

# %%
#For reading csv files
df = pd.read_csv("C:/Users/Saurav Yadav/Downloads/heart_attack_dataset.csv")

# %%
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type                            Treatment
# ...

# %%
type(df)  #this data is in form of dataFrame it is 2d data
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()  #for reading specific rows but by defualt it take first 5 rows
# Out:
#    Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0    Male   70                    181                  262           No
# 1  Female   55                    103                  253          Yes
# 2    Male   42                     95                  295          Yes
# 3    Male   84                    106                  270           No
# 4    Male   86                    187                  296          Yes
#
#   Smoking Status   Chest Pain Type                            Treatment
# 0          Never    Typical Angina                    Lifestyle Changes
# 1          Never   Atypical Angina                          Angioplasty
# 2        Current    Typical Angina                          Angioplasty
# 3          Never   Atypical Angina  Coronary Artery Bypass Graft (CABG)
# 4        Current  Non-anginal Pain                           Medication

# %%
df.head(10)   #for first 10 rows
# Out:
#    Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0    Male   70                    181                  262           No
# 1  Female   55                    103                  253          Yes
# 2    Male   42                     95                  295          Yes
# 3    Male   84                    106                  270           No
# 4    Male   86                    187                  296          Yes
# 5  Female   66                    125                  271          Yes
# 6    Male   33                    181                  262          Yes
# 7    Male   84                    182                  288           No
# 8    Male   73                    115                  286          Yes
# 9  Female   63                    174                  254          Yes
#
#   Smoking Status   Chest Pain Type                            Treatment
# 0          Never    Typical Angina                    Lifestyle Changes
# ...

# %%
df.tail()   #for reading last rows but by defualt it take first 5 rows
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type                            Treatment
# 995        Current    Typical Angina                          Angioplasty
# 996          Never   Atypical Angina  Coronary Artery Bypass Graft (CABG)
# 997        Current  Non-anginal Pain  Coronary Artery Bypass Graft (CABG)
# 998        Current      Asymptomatic                    Lifestyle Changes
# 999         Former   Atypical Angina                    Lifestyle Changes

# %%
df.tail(10)  #for last 10 rows
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 990  Female   85                    168                  208          Yes
# 991  Female   72                    194                  181           No
# 992  Female   77                     90                  276          Yes
# 993  Female   77                    198                  268          Yes
# 994  Female   51                    107                  217          Yes
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type                            Treatment
# 990          Never      Asymptomatic                    Lifestyle Changes
# ...

# %%
df.columns   #for columns name
# Out:
# Index(['Gender', 'Age', 'Blood Pressure (mmHg)', 'Cholesterol (mg/dL)',
#        'Has Diabetes', 'Smoking Status', 'Chest Pain Type', 'Treatment'],
#       dtype='object')

# %%
df["Age"]  #for singal columns selection
# Out:
# 0      70
# 1      55
# 2      42
# 3      84
# 4      86
#        ..
# 995    42
# 996    80
# 997    64
# 998    84
# 999    61
# Name: Age, Length: 1000, dtype: int64

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
# Here we can see df["Age"] in series form in 1d form

# %%
#For converting series data into datafram form
df[["Age"]]
#now it is converted into dataframe formate into 2d form
# Out:
#      Age
# 0     70
# 1     55
# 2     42
# 3     84
# 4     86
# ..   ...
# 995   42
# 996   80
# 997   64
# 998   84
# 999   61
#
# [1000 rows x 1 columns]

# %%
#For selecting more than one columns 
df[['Gender', 'Age']]
# Out:
#      Gender  Age
# 0      Male   70
# 1    Female   55
# 2      Male   42
# 3      Male   84
# 4      Male   86
# ..      ...  ...
# 995    Male   42
# 996    Male   80
# 997  Female   64
# 998  Female   84
# 999    Male   61
#
# [1000 rows x 2 columns]

# %%
#For checking the type of columns 
df.dtypes
# Out:
# Gender                   object
# Age                       int64
# Blood Pressure (mmHg)     int64
# Cholesterol (mg/dL)       int64
# Has Diabetes             object
# Smoking Status           object
# Chest Pain Type          object
# Treatment                object
# dtype: object

# %% [markdown]
# ## Working with Excel sheet

# %%
import pandas as pd

# %%
df1 = pd.read_excel("C:/Users/Saurav Yadav/Downloads/Titanic.xlsx")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Unnamed: 12    float64
# Unnamed: 13    float64
# Unnamed: 14    float64
# Unnamed: 15    float64
# Unnamed: 16    float64
# Unnamed: 17    float64
# Unnamed: 18    float64
# Unnamed: 19    float64
# Unnamed: 20    float64
# Unnamed: 21    float64
# Unnamed: 22    float64
# Unnamed: 23    float64
# Unnamed: 24    float64
# Unnamed: 25     object
# dtype: object

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Unnamed: 16 Unnamed: 17  Unnamed: 18  \
# 0      0         A/5 21171   7.2500  ...         NaN         NaN          NaN
# 1      0          PC 17599  71.2833  ...         NaN         NaN          NaN
# 2      0  STON/O2. 3101282   7.9250  ...         NaN         NaN          NaN
# ...

# %%
df1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare  ... Unnamed: 16  \
# 886    male  27.0      0      0      211536  13.00  ...         NaN
# 887  female  19.0      0      0      112053  30.00  ...         NaN
# 888  female   NaN      1      2  W./C. 6607  23.45  ...         NaN
# 889    male  26.0      0      0      111369  30.00  ...         NaN
# 890    male  32.0      0      0      370376   7.75  ...         NaN
#
#     Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# ...

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')

# %%
df1['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df1[["Name"]]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
df1[['PassengerId', 'Survived']]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %% [markdown]
# ## Reading data from link

# %%
df2 = pd.read_csv("http://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df2['Name'])
# Out:
# pandas.core.series.Series

# %%
df2[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
type(df2[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df2[['PassengerId', 'Survived']]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Working with HTML Data

# %%
pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
df3 = pd.read_html("https://www.basketball-reference.com/leagues/")

# %%
df3
# Out:
# [   Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0 Award Winners  \
#                 Season                 Lg               Champion           MVP
#  0             2024-25                NBA                    NaN           NaN
#  1             2023-24                NBA         Boston Celtics      N. Jokić
#  2             2022-23                NBA         Denver Nuggets     J. Embiid
#  3             2021-22                NBA  Golden State Warriors      N. Jokić
#  4             2020-21                NBA        Milwaukee Bucks      N. Jokić
#  ..                ...                ...                    ...           ...
#  83            1950-51                NBA       Rochester Royals           NaN
#  84            1949-50                NBA     Minneapolis Lakers           NaN
#  85            1948-49                BAA     Minneapolis Lakers           NaN
#  86            1947-48                BAA      Baltimore Bullets           NaN
# ...

# %%
type(df3)
# Out:
# list

# %%
len(df3)
# Out:
# 1
